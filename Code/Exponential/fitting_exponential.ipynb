# %%
import os 
import matplotlib as mpl

os.environ["PATH"] += r";C:\Users\Abigail Crowther\AppData\Local\Programs\MiKTeX\miktex\bin\x64" 

mpl.rcParams.update({ "text.usetex": True, "font.family": "serif", "text.latex.preamble": r"\usepackage{amsmath}\usepackage{amssymb}" }) 

os.chdir(r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Code")

# %%
import os
import numpy as np

filter_folder = r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Data\starburst_filters"
global_min = np.inf
global_max = -np.inf

for fname in os.listdir(filter_folder):
    if fname.endswith(".txt"):

        filepath = os.path.join(filter_folder, fname)
        data = np.loadtxt(filepath)

        lam_min = data[:, 0].min()
        lam_max = data[:, 0].max()

        global_min = min(global_min, lam_min)
        global_max = max(global_max, lam_max)

        print(f"{fname:20s}  {lam_min:.0f} – {lam_max:.0f} Å")

print("\nOverall wavelength coverage:")
print(f"{global_min:.0f} – {global_max:.0f} Å")
# Out:
# HST_ACS_WFC_F435W.txt  3526 – 4979 Å
# HST_ACS_WFC_F606W.txt  4569 – 7283 Å
# HST_ACS_WFC_F814W.txt  6738 – 9778 Å
# HST_WFC3_IR_F105W.txt  8650 – 12250 Å
# HST_WFC3_IR_F125W.txt  10640 – 14390 Å
# HST_WFC3_IR_F140W.txt  11370 – 16450 Å
# HST_WFC3_IR_F160W.txt  13664 – 17205 Å
# JWST_NIRCam_F090W.txt  7836 – 10356 Å
# JWST_NIRCam_F115W.txt  9892 – 13282 Å
# JWST_NIRCam_F150W.txt  12798 – 17238 Å
# JWST_NIRCam_F200W.txt  16904 – 22984 Å
# JWST_NIRCam_F277W.txt  23371 – 33015 Å
# JWST_NIRCam_F356W.txt  29930 – 42294 Å
# JWST_NIRCam_F410M.txt  36740 – 45226 Å
# JWST_NIRCam_F444W.txt  37132 – 50996 Å
#
# Overall wavelength coverage:
# 3526 – 50996 Å

# %%
import os
import numpy as np

filter_folder = r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Data\starburst_filters"

filter_files = [
    os.path.join(filter_folder, f)
    for f in os.listdir(filter_folder)
    if f.endswith(".txt")
]

filter_files.sort()

print(filter_files)
# Out:
# ['D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F435W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F606W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F814W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F105W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F125W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F140W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F160W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F090W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F115W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F150W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F200W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F277W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F356W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F410M.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F444W.txt']

# %%
import bagpipes as pipes
import numpy as np
import matplotlib.pyplot as plt

ages_myr_1 = np.arange(0,110,10)
ages_myr_2 = np.arange(200, 1100, 100)

years = np.concatenate([ages_myr_1, ages_myr_2]) / 1000
# Out:
# Bagpipes: PyMultiNest import failed, fitting will use the Nautilus sampler instead.

# %%
dust = {}
dust["type"] = "Calzetti"
dust["Av"] = 0.2
dust["eta"] = 2. #multiplies Av - extra dust for young stars

nebular = {}   #nebular emission component
nebular["logU"] = -3.   #log_10(ionization parameter)

# %%
fits = []

for t in years:

    burst = {
        "age": t,
        "massformed": 10,
        "metallicity": 0.5
    }

    model_components = {
        "redshift": 2,
        "burst": burst,
        "dust": dust,
        "nebular": nebular,
        "t_bc": 0.01,
        "veldisp": 200.
    }

    model = pipes.model_galaxy(
        model_components,
        filt_list=filter_files,
        spec_wavs=np.arange(global_min - 500,
                            global_max + 500,
                            5.),
    )

    flux_lambda = np.array(model.photometry)   # erg/s/cm^2/Å

    # effective wavelengths in Å
    filter_wavelengths = []

    for ffile in filter_files:
        filt_data = np.loadtxt(ffile)
        wave = filt_data[:,0]
        transmission = filt_data[:,1]
        eff_wave = np.sum(wave * transmission) / np.sum(transmission)
        filter_wavelengths.append(eff_wave)

    filter_wavelengths = np.array(filter_wavelengths)

    # Convert F_lambda -> F_nu (µJy)
    c = 2.99792458e18  # speed of light in Å/s

    flux_nu = flux_lambda * (filter_wavelengths**2) / c
    flux_nu = flux_nu / 1e-23      # convert to Jy
    flux_nu = flux_nu * 1e6        # Jy -> µJy

    fluxes = flux_nu
    fluxes_error = fluxes / 10.0

    galaxy_photometry = np.c_[fluxes, fluxes_error]

    def load_synthetic(ID):
        return galaxy_photometry

    galaxy = pipes.galaxy(
        f"age_{t:.2f}Gyr_exp",
        load_synthetic,
        spectrum_exists=False,
        photometry_exists=True,
        filt_list=filter_files
    )

    fit_info = {
        "redshift": 2.0,
        "exponential": {
            "massformed": (5., 12.),
            "metallicity": (0.0001, 2.),
            "metallicity_prior": "log_10",
            "age": (0.001, 1.0),
            "tau": (0.001, 5.)
        },
        "dust": {
            "type": "Calzetti",
            "Av": (0., 2.),
            "eta": (2)
        },
        "nebular": {
            "logU": (-4., -2.)
        }
    }

    fit = pipes.fit(galaxy, fit_info, run="Exponential_z2")
    fit.fit(verbose=True)

    fits.append(fit)
    print(f"Finished fitting age {t} Gyr")
# Out:
# Results loaded from pipes/posterior/Exponential_z2/age_0.00Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.00Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.0 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.01Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.01Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.01 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.02Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.02Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.02 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.03Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.03Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.03 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.04Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.04Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.04 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.05Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.05Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.05 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.06Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.06Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.06 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.07Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.07Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.07 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.08Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.08Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.08 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.09Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.09Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.09 Gyr
#
# Results loaded from pipes/posterior/Exponential_z2/age_0.10Gyr_exp.h5
#
# Fitting not performed as results have already been loaded from pipes/posterior/Exponential_z2/age_0.10Gyr_exp.h5. To start over delete this file or change run.
#
# Finished fitting age 0.1 Gyr
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 20
#       5 burst = {
#       6     "age": t,
#       7     "massformed": 10,
#       8     "metallicity": 0.5
#       9 }
#      11 model_components = {
#      12     "redshift": 2,
#      13     "burst": burst,
#    (...)
#      17     "veldisp": 200.
#      18 }
# ---> 20 model = pipes.model_galaxy(
#      21     model_components,
#      22     filt_list=filter_files,
#      23     spec_wavs=np.arange(global_min - 500,
#      24                         global_max + 500,
#      25                         5.),
#      26 )
#      28 flux_lambda = np.array(model.photometry)   # erg/s/cm^2/Å
#      30 # effective wavelengths in Å
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\models\model_galaxy.py:101, in model_galaxy.__init__(self, model_components, filt_list, spec_wavs, spec_units, phot_units, index_list)
#      99 # Create relevant physical models.
#     100 self.sfh = star_formation_history(model_components)
# --> 101 self.stellar = stellar(self.wavelengths)
#     102 self.igm = igm(self.wavelengths)
#     103 self.nebular = False
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\models\stellar_model.py:24, in stellar.__init__(self, wavelengths)
#      22 # Resample the grid in wavelength and then in age.
#      23 grid_raw_ages = self._resample_in_wavelength()
# ---> 24 self.grid = self._resample_in_age(grid_raw_ages)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\models\stellar_model.py:96, in stellar._resample_in_age(self, grid_raw_ages)
#      92 raw_age_widths[stop] *= end_fact
#      94 width_slice = raw_age_widths[start:stop + 1]
# ---> 96 summed = np.sum(np.expand_dims(width_slice, axis=0)
#      97                 * grid_raw_ages[:, :, start:stop + 1], axis=2)
#      99 grid[:, :, j] = summed/np.sum(width_slice)
#     101 raw_age_widths[start] /= start_fact
#
# KeyboardInterrupt:

# %%
for fit, age in zip(fits, years):
    print(f"\nPlots for {age:.2f} Gyr:\n")
    fit.plot_spectrum_posterior(save=False, show=True)
    fit.plot_sfh_posterior(save=False, show=True)
    fit.plot_corner(save=False, show=True)
# Out:
# Plots for 0.00 Gyr:
# Plots for 0.01 Gyr:
# Plots for 0.02 Gyr:
# Plots for 0.03 Gyr:
# Plots for 0.04 Gyr:
# Plots for 0.05 Gyr:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 5
#       3 fit.plot_spectrum_posterior(save=False, show=True)
#       4 fit.plot_sfh_posterior(save=False, show=True)
# ----> 5 fit.plot_corner(save=False, show=True)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\fitting\fit.py:333, in fit.plot_corner(self, show, save)
#     332 def plot_corner(self, show=False, save=True):
# --> 333     return plotting.plot_corner(self, show=show, save=save)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\plotting\plot_corner.py:59, in plot_corner(fit, show, save, bins, type)
#      56             labels[i] = "t" + str(t_percentile) + " / Gyr"
#      58 # Make the corner plot
# ---> 59 fig = corner.corner(samples, labels=labels, quantiles=[0.16, 0.5, 0.84],
#      60                     show_titles=True, title_kwargs={"fontsize": 13},
#      61                     smooth=1., smooth1d=1., bins=bins)
#      63 # Save the corner plot to file
#      64 if save:
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\corner\corner.py:248, in corner(data, bins, range, axes_scale, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_quantiles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     236     if (
#     237         var_names is not None
#     238         or filter_vars is not None
#    (...)
#     242         or labeller is not None
#     243     ):
#     244         logging.warning(
#     245             "Please install arviz to use the advanced features of corner"
#     246         )
# --> 248     return corner_impl(
#     249         data,
#     250         bins=bins,
#     251         range=range,
#     252         axes_scale=axes_scale,
#     253         weights=weights,
#     254         color=color,
#     255         hist_bin_factor=hist_bin_factor,
#     256         smooth=smooth,
#     257         smooth1d=smooth1d,
#     258         labels=labels,
#     259         label_kwargs=label_kwargs,
#     260         titles=titles,
#     261         show_titles=show_titles,
#     262         title_quantiles=title_quantiles,
#     263         title_fmt=title_fmt,
#     264         title_kwargs=title_kwargs,
#     265         truths=truths,
#     266         truth_color=truth_color,
#     267         scale_hist=scale_hist,
#     268         quantiles=quantiles,
#     269         verbose=verbose,
#     270         fig=fig,
#     271         max_n_ticks=max_n_ticks,
#     272         top_ticks=top_ticks,
#     273         use_math_text=use_math_text,
#     274         reverse=reverse,
#     275         labelpad=labelpad,
#     276         hist_kwargs=hist_kwargs,
#     277         **hist2d_kwargs,
#     278     )
#     280 return arviz_corner(
#     281     data,
#     282     bins=bins,
#    (...)
#     316     **hist2d_kwargs,
#     317 )
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\corner\core.py:126, in corner_impl(xs, bins, range, axes_scale, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, title_quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     124 new_fig = True
#     125 if fig is None:
# --> 126     fig, axes = pl.subplots(K, K, figsize=(dim, dim))
#     127 else:
#     128     axes, new_fig = _get_fig_axes(fig, K)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\pyplot.py:1760, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1615 """
#    1616 Create a figure and a set of subplots.
#    1617
#    (...)
#    1757
#    1758 """
#    1759 fig = figure(**fig_kw)
# -> 1760 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1761                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1762                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1763                    width_ratios=width_ratios)
#    1764 return fig, axs
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\figure.py:861, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     858     gridspec_kw['width_ratios'] = width_ratios
#     860 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 861 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     862                   subplot_kw=subplot_kw)
#     863 return axs
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\gridspec.py:283, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     281         subplot_kw["sharex"] = shared_with[sharex]
#     282         subplot_kw["sharey"] = shared_with[sharey]
# --> 283         axarr[row, col] = figure.add_subplot(
#     284             self[row, col], **subplot_kw)
#     286 # turn off redundant tick labeling
#     287 if sharex in ["col", "all"]:
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\figure.py:710, in FigureBase.add_subplot(self, *args, **kwargs)
#     708         args = tuple(map(int, str(args[0])))
#     709     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 710     ax = projection_class(self, *args, **pkw)
#     711     key = (projection_class, pkw)
#     712 return self._add_axes_internal(ax, key)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\axes\_base.py:640, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     638     self._position = mtransforms.Bbox.from_bounds(*args[0])
#     639 else:
# --> 640     self._position = self._originalPosition = mtransforms.Bbox.unit()
#     641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\transforms.py:798, in Bbox.unit()
#     795 @staticmethod
#     796 def unit():
#     797     """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 798     return Bbox([[0, 0], [1, 1]])
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\matplotlib\transforms.py:772, in Bbox.__init__(self, points, **kwargs)
#     769     raise ValueError('Bbox points must be of the form '
#     770                      '"[[x0, y0], [x1, y1]]".')
#     771 self._points = points
# --> 772 self._minpos = _default_minpos.copy()
#     773 self._ignore = True
#     774 # it is helpful in some contexts to know if the bbox is a
#     775 # default or has been mutated; we store the orig points to
#     776 # support the mutated methods
#
# KeyboardInterrupt:
