# %%
import os 
import matplotlib as mpl

os.environ["PATH"] += r";C:\Users\Abigail Crowther\AppData\Local\Programs\MiKTeX\miktex\bin\x64" 

mpl.rcParams.update({ "text.usetex": True, "font.family": "serif", "text.latex.preamble": r"\usepackage{amsmath}\usepackage{amssymb}" }) 

os.chdir(r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Code")

# %%
import os
import numpy as np

filter_folder = r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Data\starburst_filters"
global_min = np.inf
global_max = -np.inf

for fname in os.listdir(filter_folder):
    if fname.endswith(".txt"):

        filepath = os.path.join(filter_folder, fname)
        data = np.loadtxt(filepath)

        lam_min = data[:, 0].min()
        lam_max = data[:, 0].max()

        global_min = min(global_min, lam_min)
        global_max = max(global_max, lam_max)

        print(f"{fname:20s}  {lam_min:.0f} – {lam_max:.0f} Å")

print("\nOverall wavelength coverage:")
print(f"{global_min:.0f} – {global_max:.0f} Å")
# Out:
# HST_ACS_WFC_F435W.txt  3526 – 4979 Å
# HST_ACS_WFC_F606W.txt  4569 – 7283 Å
# HST_ACS_WFC_F814W.txt  6738 – 9778 Å
# HST_WFC3_IR_F105W.txt  8650 – 12250 Å
# HST_WFC3_IR_F125W.txt  10640 – 14390 Å
# HST_WFC3_IR_F140W.txt  11370 – 16450 Å
# HST_WFC3_IR_F160W.txt  13664 – 17205 Å
# JWST_NIRCam_F090W.txt  7836 – 10356 Å
# JWST_NIRCam_F115W.txt  9892 – 13282 Å
# JWST_NIRCam_F150W.txt  12798 – 17238 Å
# JWST_NIRCam_F200W.txt  16904 – 22984 Å
# JWST_NIRCam_F277W.txt  23371 – 33015 Å
# JWST_NIRCam_F356W.txt  29930 – 42294 Å
# JWST_NIRCam_F410M.txt  36740 – 45226 Å
# JWST_NIRCam_F444W.txt  37132 – 50996 Å
#
# Overall wavelength coverage:
# 3526 – 50996 Å

# %%
import os
import numpy as np

filter_folder = r"D:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\star-formation-histories\Data\starburst_filters"

filter_files = [
    os.path.join(filter_folder, f)
    for f in os.listdir(filter_folder)
    if f.endswith(".txt")
]

filter_files.sort()

print(filter_files)
# Out:
# ['D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F435W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F606W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_ACS_WFC_F814W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F105W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F125W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F140W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\HST_WFC3_IR_F160W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F090W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F115W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F150W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F200W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F277W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F356W.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F410M.txt', 'D:\\Users\\Abigail Crowther\\Desktop\\Uni\\Year 4\\MPhys Projects\\Semester 2 - Star Formation Histories\\star-formation-histories\\Data\\starburst_filters\\JWST_NIRCam_F444W.txt']

# %%
import bagpipes as pipes
import numpy as np
import matplotlib.pyplot as plt

ages_myr_1 = np.arange(0,110,10)
ages_myr_2 = np.arange(200, 1100, 100)

years = np.concatenate([ages_myr_1, ages_myr_2]) / 1000

# %%
dust = {}
dust["type"] = "Calzetti"
dust["Av"] = 0.2
dust["eta"] = 2. #multiplies Av - extra dust for young stars

nebular = {}   #nebular emission component
nebular["logU"] = -3.   #log_10(ionization parameter)

z = 4

# %%
fits = []

for t in years:

    burst = {
        "age": t,
        "massformed": 10,
        "metallicity": 0.5
    }

    model_components = {
        "redshift": z,
        "burst": burst,
        "dust": dust,
        "nebular": nebular,
        "t_bc": 0.01,
        "veldisp": 200.
    }

    model = pipes.model_galaxy(
        model_components,
        filt_list=filter_files,
        spec_wavs=np.arange(global_min - 500,
                            global_max + 500,
                            5.),
    )

    flux_lambda = np.array(model.photometry)   # erg/s/cm^2/Å

    # effective wavelengths in Å
    filter_wavelengths = []

    for ffile in filter_files:
        filt_data = np.loadtxt(ffile)
        wave = filt_data[:,0]
        transmission = filt_data[:,1]
        eff_wave = np.sum(wave * transmission) / np.sum(transmission)
        filter_wavelengths.append(eff_wave)

    filter_wavelengths = np.array(filter_wavelengths)

    # Convert F_lambda -> F_nu (µJy)
    c = 2.99792458e18  # speed of light in Å/s

    flux_nu = flux_lambda * (filter_wavelengths**2) / c
    flux_nu = flux_nu / 1e-23      # convert to Jy
    flux_nu = flux_nu * 1e6        # Jy -> µJy

    fluxes = flux_nu
    fluxes_error = fluxes / 10.0

    galaxy_photometry = np.c_[fluxes, fluxes_error]

    def load_synthetic(ID):
        return galaxy_photometry

    galaxy = pipes.galaxy(
        f"{t:.1f}",
        load_synthetic,
        spectrum_exists=False,
        photometry_exists=True,
        filt_list=filter_files
    )

    fit_info = {
        "redshift": z,
        "exponential": {
            "massformed": (5., 12.),
            "metallicity": (0.0001, 2.),
            "metallicity_prior": "log_10",
            "age": (0.001, 1.0),
            "tau": (0.001, 5.)
        },
        "dust": {
            "type": "Calzetti",
            "Av": (0., 2.),
            "eta": (2)
        },
        "nebular": {
            "logU": (-4., -2.)
        }
    }

    fit = pipes.fit(galaxy, fit_info, run=f"dpl/z_{z}")
    fit.fit(verbose=True)

    fits.append(fit)
    print(f"Finished fitting age {t} Gyr")
# Out:
# MultiNest not available. Switching to nautilus.
#
# Bagpipes: fitting object 0.0
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Computing | 1      | 0        | 0        | 100      | 1.0000 | 1     | +422.09
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 85
#      65 fit_info = {
#      66     "redshift": z,
#      67     "exponential": {
#    (...)
#      81     }
#      82 }
#      84 fit = pipes.fit(galaxy, fit_info, run="dpl/z_{2}")
# ---> 85 fit.fit(verbose=True)
#      87 fits.append(fit)
#      88 print(f"Finished fitting age {t} Gyr")
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\fitting\fit.py:240, in fit.fit(self, verbose, n_live, use_MPI, sampler, n_eff, discard_exploration, n_networks, pool)
#     233     elif sampler == "nautilus":
#     234         n_sampler = Sampler(self.fitted_model.prior.transform,
#     235                             self.fitted_model.lnlike, n_live=n_live,
#     236                             n_networks=n_networks, pool=pool,
#     237                             n_dim=self.fitted_model.ndim,
#     238                             filepath=self.fname + ".h5")
# --> 240         n_sampler.run(verbose=verbose, n_eff=n_eff,
#     241                       discard_exploration=discard_exploration)
#     243     os.environ["PYTHONWARNINGS"] = ""
#     245 if rank == 0 or not use_MPI:
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\nautilus\sampler.py:447, in Sampler.run(self, f_live, n_shell, n_eff, n_like_max, discard_exploration, timeout, verbose)
#     444     if self.filepath is not None:
#     445         self.write(self.filepath, overwrite=True)
# --> 447 self.n_update_iter += self.add_samples(-1, verbose=verbose)
#     448 self.n_like_iter += self.n_batch
#     449 if self.filepath is not None:
#     450     # Write the complete file if this is the first batch.
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\nautilus\sampler.py:1134, in Sampler.add_samples(self, shell, verbose)
#    1131         self.print_status('Computing', end='\r')
#    1133 self.shell_n_sample[shell] += n_bound
# -> 1134 log_l, blobs = self.evaluate_likelihood(points)
#    1135 self.points[shell] = np.append(self.points[shell], points, axis=0)
#    1136 self.log_l[shell] = np.append(self.log_l[shell], log_l, axis=0)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\nautilus\sampler.py:873, in Sampler.evaluate_likelihood(self, points)
#     871     result = list(self.pool_l.map(self.likelihood, args))
#     872 else:
# --> 873     result = list(map(self.likelihood, args))
#     875 # Extracts the blobs, if present.
#     876 if isinstance(result[0], tuple):
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\fitting\fitted_model.py:153, in fitted_model.lnlike(self, x, ndim, nparam)
#     145 if self.model_galaxy is None:
#     146     self.model_galaxy = model_galaxy(self.model_components,
#     147                                      filt_list=self.galaxy.filt_list,
#     148                                      spec_wavs=self.galaxy.spec_wavs,
#     149                                      index_list=self.galaxy.index_list,
#     150                                      spec_units=self.galaxy.out_units,
#     151                                      phot_units=self.galaxy.out_units)
# --> 153 self.model_galaxy.update(self.model_components)
#     155 # Return zero likelihood if SFH is older than the universe.
#     156 if self.model_galaxy.sfh.unphysical:
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\models\model_galaxy.py:303, in model_galaxy.update(self, model_components)
#     300     self.uvj = np.zeros(3)
#     302 else:
# --> 303     self._calculate_full_spectrum(model_components)
#     305 if self.spec_wavs is not None:
#     306     self._calculate_spectrum(model_components)
#
# File d:\Users\Abigail Crowther\Desktop\Uni\Year 4\MPhys Projects\Semester 2 - Star Formation Histories\bagpipesenv\lib\site-packages\bagpipes\models\model_galaxy.py:426, in model_galaxy._calculate_full_spectrum(self, model_comp)
#     424 # Add attenuation due to the diffuse ISM.
#     425 if self.dust_atten:
# --> 426     trans = 10**(-model_comp["dust"]["Av"]*self.dust_atten.A_cont/2.5)
#     427     dust_spectrum = spectrum*trans
#     428     dust_spectrum_bc = spectrum_bc*trans
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plotting fit SFH

# %%
import numpy as np
from bagpipes import utils

# redshift
if "redshift" in fit.fitted_model.params:
    redshift = np.median(fit.posterior.samples["redshift"])
else:
    redshift = fit.fitted_model.model_components["redshift"]

age_of_universe = np.interp(redshift, utils.z_array, utils.age_at_z)

# SFH posterior
post = np.percentile(fit.posterior.samples["sfh"], (16, 50, 84), axis=0).T

x = age_of_universe - fit.posterior.sfh.ages * 1e-9
median_sfr = post[:,1]
lower_sfr = post[:,0]
upper_sfr = post[:,2]

# %%
import matplotlib.pyplot as plt
import numpy as np
from bagpipes import utils

age_universe_fit = np.interp(z_fit, utils.z_array, utils.age_at_z)

lookback = fit.posterior.sfh.ages * 1e-9
cosmic_age = age_universe_fit - lookback

order = np.argsort(cosmic_age)
x = cosmic_age[order]
median_sfr = median_sfr[order]
lower_sfr = lower_sfr[order]
upper_sfr = upper_sfr[order]

fig, ax = plt.subplots(figsize=(12,4))

ax.plot(x, median_sfr)
ax.fill_between(x, lower_sfr, upper_sfr, alpha=0.3)

ax.set_xlim(max(x), 0)

ax.set_xlabel("Age of Universe (Gyr)")
ax.set_ylabel("SFR (M$_\odot$ yr$^{-1}$)")

ax_top = ax.twiny()
zvals = [0,0.5,1,2,4,10]
ages = np.interp(zvals, utils.z_array, utils.age_at_z)

ax_top.set_xlim(ax.get_xlim())
ax_top.set_xticks(ages)
ax_top.set_xticklabels(zvals)
ax_top.set_xlabel("Redshift")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       2 import numpy as np
#       3 from bagpipes import utils
# ----> 5 age_universe_fit = np.interp(z_fit, utils.z_array, utils.age_at_z)
#       7 lookback = fit.posterior.sfh.ages * 1e-9
#       8 cosmic_age = age_universe_fit - lookback
#
# NameError: name 'z_fit' is not defined

# %% [markdown]
# ### Plotting model SFH

# %%
import matplotlib as mpl
import os

os.environ["PATH"] += r";C:\Users\Abigail Crowther\AppData\Local\Programs\MiKTeX\miktex\bin\x64"

mpl.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "text.latex.preamble": r"\usepackage{amsmath}\usepackage{amssymb}"
})

# %%
import matplotlib.pyplot as plt
import numpy as np
from bagpipes import utils

burst_age = 1.0
z_model = z
M_target = 1e10        
metallicity = 0.5

age_of_universe = np.interp(z_model, utils.z_array, utils.age_at_z)

n_bins = 1000
ages_array = np.linspace(0, age_of_universe, n_bins)

sigma = (ages_array.max() - ages_array.min()) * 0.01
burst_center = age_of_universe - burst_age
sfr_unnorm = np.exp(-(ages_array - burst_center)**2 / (2 * sigma**2))

integral = np.trapz(sfr_unnorm, ages_array * 1e9)  # convert Gyr → yr
scale = M_target / integral
sfr_array = scale * sfr_unnorm

fig, ax = plt.subplots(figsize=(12,4))
ax.plot(ages_array, sfr_array, color="blue",
        label=f"Burst at {burst_age} Gyr (M = 1e10 Msun)")

ax.set_xlim(age_of_universe, 0)

ax.set_xlabel("Age of Universe (Gyr)")
ax.set_ylabel(r"SFR ($M_\odot\,\mathrm{yr}^{-1}$)")
ax.legend()

ax_top = ax.twiny()
zvals = [0, 0.5, 1, 2, 4, 10]
ages_top = np.interp(zvals, utils.z_array, utils.age_at_z)
ax_top.set_xlim(ax.get_xlim())
ax_top.set_xticks(ages_top)
ax_top.set_xticklabels(zvals)
ax_top.set_xlabel("Redshift")

plt.show()

# %% [markdown]
# ### Overlaying plots of model and posterior SFHs

# %%
import matplotlib.pyplot as plt
import numpy as np
from bagpipes import utils

fig, ax = plt.subplots(figsize=(12,4))

ax.plot(x, median_sfr, color="red", label="Recovered SFH")
ax.fill_between(x, lower_sfr, upper_sfr, color="red", alpha=0.3)

burst_age = 1.0
z_model = z
M_target = 1e10

age_of_universe = np.interp(z_model, utils.z_array, utils.age_at_z)

n_bins = 1000
ages_array = np.linspace(0, age_of_universe, n_bins)

sigma = (ages_array.max() - ages_array.min()) * 0.01
burst_center = age_of_universe - burst_age
sfr_unnorm = np.exp(-(ages_array - burst_center)**2 / (2 * sigma**2))

integral = np.trapz(sfr_unnorm, ages_array * 1e9)
scale = M_target / integral
sfr_array = scale * sfr_unnorm

ax.plot(ages_array, sfr_array, color="blue", label=f"True Burst at {burst_age} Gyr")

ax.set_xlim(max(x), 0)
ax.set_xlabel("Age of Universe (Gyr)")
ax.set_ylabel(r"SFR ($M_\odot\,\mathrm{yr}^{-1}$)")
ax.legend()

ax_top = ax.twiny()
zvals = [0,0.5,1,2,4,10]
ages_top = np.interp(zvals, utils.z_array, utils.age_at_z)
ax_top.set_xlim(ax.get_xlim())
ax_top.set_xticks(ages_top)
ax_top.set_xticklabels(zvals)
ax_top.set_xlabel("Redshift")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from bagpipes import utils

z_model = z
M_target = 1e10  # desired total formed mass

for i, burst_age in enumerate(years):

    age_of_universe = np.interp(z_model, utils.z_array, utils.age_at_z)

    n_bins = 1000
    ages_array = np.linspace(0, age_of_universe, n_bins)

    sigma = (ages_array.max() - ages_array.min()) * 0.01
    burst_center = age_of_universe - burst_age
    sfr_unnorm = np.exp(-(ages_array - burst_center)**2 / (2 * sigma**2))

    integral = np.trapz(sfr_unnorm, ages_array * 1e9)  # Gyr→yr
    scale = M_target / integral
    sfr_array = scale * sfr_unnorm

    fig, ax = plt.subplots(figsize=(12, 4))

    ax.plot(ages_array, sfr_array, color="blue",
            label=f"True Burst at {burst_age:.2f} Gyr")

    fit = fits[i]

    if "redshift" in fit.fitted_model.params:
        z_fit = np.median(fit.posterior.samples["redshift"])
    else:
        z_fit = fit.fitted_model.model_components["redshift"]

    age_of_universe_fit = np.interp(z_fit, utils.z_array, utils.age_at_z)

    post = np.percentile(fit.posterior.samples["sfh"], (16, 50, 84), axis=0).T
    x = age_of_universe_fit - fit.posterior.sfh.ages * 1e-9  # lookback→age

    ax.plot(x, post[:, 1], color="red", alpha=0.7, label="Recovered SFH")
    ax.fill_between(x, post[:, 0], post[:, 2], color="red", alpha=0.2)

    ax.set_xlim(max(x), 0)
    ax.set_xlabel("Age of Universe (Gyr)")
    ax.set_ylabel(r"SFR ($M_\odot\,\mathrm{yr}^{-1}$)")
    ax.legend()

    ax_top = ax.twiny()
    zvals = [0, 0.5, 1, 2, 4, 10]
    ages_top = np.interp(zvals, utils.z_array, utils.age_at_z)
    ax_top.set_xlim(ax.get_xlim())
    ax_top.set_xticks(ages_top)
    ax_top.set_xticklabels(zvals)
    ax_top.set_xlabel("Redshift")

    plt.show()

# %%
# After computing sfr_array and ages_array
M_true = np.trapz(sfr_array, ages_array * 1e9)
M_rec = 10**np.median(fit.posterior.samples["dblplaw:massformed"])

print("True mass:", M_true)
print("Recovered mass:", M_rec)
print("Difference (dex):", np.log10(M_true) - np.log10(M_rec))
# Out:
# True mass: 10000000000.000002
# Recovered mass: 20844443854.08318
# Difference (dex): -0.31899031230353003

# %%
import matplotlib.pyplot as plt
import numpy as np
from bagpipes import utils

z_model = z
M_target = 1e10   # desired total formed mass

n_rows, n_cols = 5, 4
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 15), sharex=True, sharey=True)
axes = axes.flatten()

for i, burst_age in enumerate(years):

    ax = axes[i]

    # cosmic age at model redshift 
    age_universe = np.interp(z_model, utils.z_array, utils.age_at_z)

    n_bins = 1000
    ages_array = np.linspace(0, age_universe, n_bins)

    # Gaussian burst shape (unnormalised)
    sigma = (ages_array.max() - ages_array.min()) * 0.01
    burst_center = age_universe - burst_age
    sfr_unnorm = np.exp(-(ages_array - burst_center)**2 / (2 * sigma**2))

    # normalise to total mass M_target
    integral = np.trapz(sfr_unnorm, ages_array * 1e9)  # convert Gyr→yr
    scale = M_target / integral
    sfr_array = scale * sfr_unnorm

    ax.plot(ages_array, sfr_array, color="blue",
            label=f"True Burst {burst_age:.2f} Gyr")

    fit = fits[i]

    if "redshift" in fit.fitted_model.params:
        z_fit = np.median(fit.posterior.samples["redshift"])
    else:
        z_fit = fit.fitted_model.model_components["redshift"]

    age_universe_fit = np.interp(z_fit, utils.z_array, utils.age_at_z)

    post = np.percentile(fit.posterior.samples["sfh"], (16, 50, 84), axis=0).T

    # Bagpipes ages = lookback time in years → convert to cosmic age (Gyr)
    lookback = fit.posterior.sfh.ages * 1e-9
    cosmic_age = age_universe_fit - lookback

    ax.plot(cosmic_age, post[:, 1], color="red", alpha=0.7, label="Recovered SFH")
    ax.fill_between(cosmic_age, post[:, 0], post[:, 2], color="red", alpha=0.2)

    ax.set_xlim(age_universe_fit, 0)
    ax.set_ylim(0, 370)
    ax.set_xlabel("Age of Universe (Gyr)")
    ax.set_ylabel(r"SFR ($M_\odot\,\mathrm{yr}^{-1}$)")
    ax.legend(fontsize=8)

    if i < n_cols:
        ax_top = ax.twiny()
        zvals = [0, 0.5, 1, 2, 4, 10]
        ages_top = np.interp(zvals, utils.z_array, utils.age_at_z)
        ax_top.set_xlim(ax.get_xlim())
        ax_top.set_xticks(ages_top)
        ax_top.set_xticklabels(zvals)
        ax_top.set_xlabel("Redshift")

# remove unused axes
for j in range(i+1, n_rows*n_cols):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()
